# %% [markdown]
# #**Concepts and Technologies of AI (5CS037)**
#
# Task-3 [Classification Task]
#
# Name: Suhan Shrestha
#
# University ID: 2203697
#
# Section: L5CG1
#
#
# ---

# %% [markdown]
# #**About The Dataset**
#
# The dataset I chose for the classification task is about TV series ranked according to their IMDB score and votes they got from watchers.
#
# This datatset contains 13 columns and they are listed below:
#
# 1. Poster_Link - Link of the poster that imdb using
# 2. Series_Title - Name of the series
# 3. RuntimeofSeries - Year at which series started to series end
# 4. Certificate - Certificate earned by that series
# 5. RuntimeofEpisodes - Total runtime of the episodes in series
# 6. Genre - Genre of the series
# 7. IMDBRating - Rating of the series at IMDB site
# 8. Overview - mini story/ summary
# 9. Star1 - Name of the 1st star.
# 10. Star2 - Name of the 2nd star.
# 11. Star3 - Name of the 3rd star.
# 12. Satr4 - Name of the 4th star.
# 13. No of votes - Total number of votes
#
#
# ---

# %%
## Importing necessary libraries for data cleansing 
import pandas as pd
import numpy as np

# %%
#Loading CSV/dataset in colab 
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ad99229f-ed08-4f2f-a88f-1ddf1c5c0e7b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ad99229f-ed08-4f2f-a88f-1ddf1c5c0e7b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving series_data.csv to series_data (1).csv

# %%
#importing data in Pandas
import io 
df = pd.read_csv(io.BytesIO(uploaded['series_data.csv']))

# %%
df.head()
# Out:
#                                          Poster_Link  ... No_of_Votes
# 0  https://m.media-amazon.com/images/M/MV5BYTRiND...  ...     1773458
# 1  https://m.media-amazon.com/images/M/MV5BMjhiMz...  ...     1468887
# 2  https://m.media-amazon.com/images/M/MV5BMTc5Zm...  ...      854698
# 3  https://m.media-amazon.com/images/M/MV5BNDVkYj...  ...      829816
# 4  https://m.media-amazon.com/images/M/MV5BMjEzMD...  ...      824966
#
# [5 rows x 13 columns]

# %%
## Dropping or Deleteing the rows from the dataset that we won't be needing
df.drop("Poster_Link", axis=1, inplace=True)
df.drop("Certificate", axis=1, inplace=True)
df.drop("Overview", axis=1, inplace=True)
df.drop("Star4", axis=1, inplace=True)

# %%
df.head()
# Out:
#        Series_Title Runtime_of_Series  ...            Star3 No_of_Votes
# 0   Game of Thrones       (2011–2019)  ...    Kit Harington     1773458
# 1      Breaking Bad       (2008–2013)  ...        Anna Gunn     1468887
# 2  The Walking Dead          (2010– )  ...  Melissa McBride      854698
# 3           Friends       (1994–2004)  ...      Lisa Kudrow      829816
# 4   Stranger Things          (2016– )  ...     Winona Ryder      824966
#
# [5 rows x 9 columns]

# %% [markdown]
# Here,
# 1. The 'drop' function deletes the row that we no longer need.
#
# 2. Axis value of 1 is to signify we want to delete a column.
#
# 3. An inplace value of True to make sure we delete the column from the original Dataframe. If we don’t use the inplace=True argument our drop function will return a copy of the initial Dataframe with the **"Poster_Link"** column deleted, which is sometimes not desirable if we are working with a relatively big Dataframe.
#
#
# ---

# %% [markdown]
# # Methodology
#
# Finding the oldest and the most recent TV Series on this dataset

# %%
df["Runtime_of_Series"].min()
# Out:
# '(1951–1957)'

# %%
df["Runtime_of_Series"].max()
# Out:
# '(II) (2020–2021)'

# %%
df["Runtime_of_Series"]==df["Runtime_of_Series"].min()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1995    False
# 1996    False
# 1997    False
# 1998    False
# 1999    False
# Name: Runtime_of_Series, Length: 2000, dtype: bool

# %%
df[df["Runtime_of_Series"]==df["Runtime_of_Series"].min()]
# Out:
#     Series_Title Runtime_of_Series  ...         Star3 No_of_Votes
# 657  I Love Lucy       (1951–1957)  ...  Vivian Vance       22061
#
# [1 rows x 9 columns]

# %%
df[df["Runtime_of_Series"]==df["Runtime_of_Series"].max()]
# Out:
#     Series_Title Runtime_of_Series  ...       Star3 No_of_Votes
# 807   Your Honor  (II) (2020–2021)  ...  Hope Davis       17404
#
# [1 rows x 9 columns]

# %% [markdown]
# # Findings
#
# TV series from 1951 to 2021 have been collected in this dataset. 'I Love Lucy' starring Lucille Ball, Desi Arnaz, and Vivian Vance first aired in 1951 is the oldest TV series with the IMDB rating of 8.4 in this dataset and 'Your Honor' starring Bryan Cranston, Hunter Doohan, and Hope Davis first aired in 2020 is the latest TV series with the IMDB rating of 7.9.
#
#
# ---

# %% [markdown]
# #Methodology
#
# Fidning the least fan-favorite and the most popular TV Series since 1951.

# %%
df["IMDB_Rating"].min()
# Out:
# 1.0

# %%
df["IMDB_Rating"]==df["IMDB_Rating"].min()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1995    False
# 1996    False
# 1997    False
# 1998    False
# 1999    False
# Name: IMDB_Rating, Length: 2000, dtype: bool

# %%
df[df["IMDB_Rating"]==df["IMDB_Rating"].min()]
# Out:
#                Series_Title Runtime_of_Series  ...        Star3 No_of_Votes
# 1523  Iste Bu Benim Masalim          (2021– )  ...  Merve Sevin        7560
#
# [1 rows x 9 columns]

# %%
df["IMDB_Rating"].max()
# Out:
# 9.7

# %%
df["IMDB_Rating"]==df["IMDB_Rating"].max()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1995    False
# 1996    False
# 1997    False
# 1998    False
# 1999    False
# Name: IMDB_Rating, Length: 2000, dtype: bool

# %%
df[df["IMDB_Rating"]==df["IMDB_Rating"].max()]
# Out:
#      Series_Title Runtime_of_Series  ...        Star3 No_of_Votes
# 1003   The Chosen          (2017– )  ...  Paras Patel       13085
#
# [1 rows x 9 columns]

# %% [markdown]
# #Findings
#
# 'Iste Bu Benim Masalim' is a TV series with the lowest IMDB rating with just 1.0 starring acclaimed actors like 'Aleyna Tilki', 'Cemal Can Canseven' and 'Merve Sevin'. It was first released in 2021 and is currently going. Each episode of the series is 40 minutes long and it is a Musical, Romantic series.
#
#
#
# The TV series with the highest IMDB Rating is 'The Chosen' which was first aired in 2017 and is currently running. The show stars 'Shahar Isaac', 'Jonathan Rounmie' and 'Paras Patel'. Each episode of the show is 54 minutes long and it is a Drama/History series. It has nearly 13085 votes in IMDB.
#
#
#
# ---

# %% [markdown]
# #**The Chosen**
# The Chosen is a television drama based on the life of Jesus of Nazareth, created, directed and co-written by American filmmaker Dallas Jenkins. It is the first multi-season series about the life of Jesus, and season one was the top crowd-funded TV series or film project of all time. The series' creators stated that they had hoped to distinguish the new series from previous portrayals of Jesus by crafting a multi-season, episode-based story. The series portrays Jesus "through the eyes of those who met him".
#
# The show has used innovative methods to finance its production and stream the series. The show is financed via crowdfunding; the show is free to watch and viewers are asked to "pay it forward" by contributing whatever amount they wish to fund future seasons, and contributors may receive perks such as appearing as an extra in the film. As of 2021, viewers had contributed $40 million towards its production, making it by far the most successful crowdfunded entertainment project. The show is available through a free app. It is also available on streaming platforms like Amazon Prime Video and Peacock. (Source: Wikipedia)
#
# ![375px-The_Chosen_-_logo.jpg](data:image/jpeg;base64,...)

# %%
df["IMDB_Rating"].mean()
# Out:
# 7.591300000000001

# %% [markdown]
# #Findings
# On average, TV Series get voted 7.6 out of 10 irregardless of their genre, their director, or the actors that play in the movie.
#
#
# ---

# %% [markdown]
# #Methodology
# Finding the lowest voted series and the most voted TV Series.
#
#
# ---

# %%
df["No_of_Votes"].max()
# Out:
# 1773458

# %%
df["No_of_Votes"]==df["No_of_Votes"].max()
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1995    False
# 1996    False
# 1997    False
# 1998    False
# 1999    False
# Name: No_of_Votes, Length: 2000, dtype: bool

# %%
df[df["No_of_Votes"]==df["No_of_Votes"].max()]
# Out:
#       Series_Title Runtime_of_Series  ...          Star3 No_of_Votes
# 0  Game of Thrones       (2011–2019)  ...  Kit Harington     1773458
#
# [1 rows x 9 columns]

# %%
df["No_of_Votes"].min()
# Out:
# 5109

# %%
df["No_of_Votes"]==df["No_of_Votes"].min()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1995    False
# 1996    False
# 1997    False
# 1998    False
# 1999     True
# Name: No_of_Votes, Length: 2000, dtype: bool

# %%
df[df["No_of_Votes"]==df["No_of_Votes"].min()]
# Out:
#         Series_Title Runtime_of_Series  ...        Star3 No_of_Votes
# 1999  Comic Book Men       (2012–2018)  ...  Mike Zapcic        5109
#
# [1 rows x 9 columns]

# %% [markdown]
# # Findings
# **Game of Thrones** is the most voted TV Series worldwide with the vote count of '1773458'. It was first aired in 2011. Each episode of the show is 57 minutes long and some of the most prolific actors like 'Kit Harrington', 'Peter Dinklage' and 'Emilia Clarke' star in the Show.
#
#
# **Comic Book Men** is the least votes TV Series with just '5109' votes worldide. It was first aired in 2012 and the show ended in 2018 with each episode lasting upto 22 minutes. It starred actors like 'Walter Falnagan', 'Mike Zapcic' and 'Kevin Smith'.
#
#
# ---

# %% [markdown]
# #**Game of Thrones**
#
# Game of Thrones is an American fantasy drama television series created by David Benioff and D. B. Weiss for HBO. It is an adaptation of A Song of Ice and Fire, a series of fantasy novels by George R. R. Martin, the first of which is A Game of Thrones. The show was shot in the United Kingdom, Canada, Croatia, Iceland, Malta, Morocco, and Spain. It premiered on HBO in the United States on April 17, 2011, and concluded on May 19, 2019, with 73 episodes broadcast over eight seasons.
#
# Set on the fictional continents of Westeros and Essos, Game of Thrones has a large ensemble cast and follows several story arcs throughout the course of the show. The first major arc concerns the Iron Throne of the Seven Kingdoms of Westeros through a web of political conflicts among the noble families either vying to claim the throne or fighting for independence from whoever sits on it. A second focuses on the last descendant of the realm's deposed ruling dynasty, who has been exiled to Essos and is plotting to return and reclaim the throne. The third follows the Night's Watch, a military order defending the realm against threats from beyond Westeros's northern border. (Source: Wikipedia)
#
# ![Game_of_Thrones_title_card.jpg](data:image/jpeg;base64,...)

# %%
df.dtypes
# Out:
# Series_Title            object
# Runtime_of_Series       object
# Runtime_of_Episodes     object
# Genre                   object
# IMDB_Rating            float64
# Star1                   object
# Star2                   object
# Star3                   object
# No_of_Votes              int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Series_Title         2000 non-null   object
#  1   Runtime_of_Series    2000 non-null   object
#  2   Runtime_of_Episodes  1957 non-null   object
#  3   Genre                2000 non-null   object
#  4   IMDB_Rating          2000 non-null   float64
#  5   Star1                2000 non-null   object
#  6   Star2                2000 non-null   object
#  7   Star3                1999 non-null   object
#  8   No_of_Votes          2000 non-null   int64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 140.8+ KB

# %% [markdown]
# Sorting data based on "No_of_Votes" and "IMDB_Ratings"

# %%
ratings=df.sort_values(['No_of_Votes'],ascending=False)
imdb=df.sort_values(['IMDB_Rating'],ascending=False)

# %%
df.head(15)
# Out:
#              Series_Title Runtime_of_Series  ...             Star3 No_of_Votes
# 0         Game of Thrones       (2011–2019)  ...     Kit Harington     1773458
# 1            Breaking Bad       (2008–2013)  ...         Anna Gunn     1468887
# 2        The Walking Dead          (2010– )  ...   Melissa McBride      854698
# 3                 Friends       (1994–2004)  ...       Lisa Kudrow      829816
# 4         Stranger Things          (2016– )  ...      Winona Ryder      824966
# 5                Sherlock       (2010–2017)  ...        Una Stubbs      808717
# 6     The Big Bang Theory       (2007–2019)  ...       Kaley Cuoco      724187
# 7                  Dexter       (2006–2021)  ...       David Zayas      647136
# 8   How I Met Your Mother       (2005–2014)  ...    Cobie Smulders      603824
# 9          True Detective          (2014– )  ...    Rachel McAdams      500194
# 10                   Lost       (2004–2010)  ...        Yunjin Kim      496290
# ...

# %%
## Importing necessary libraries for data visualization
import re
import string
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
# %matplotlib inline

# %% [markdown]
# #Methodology:
# Plotting the data of top 15 TV Series on a graph according to the number of votes they have gotten from the users.

# %%
fig,axs=plt.subplots(figsize=(20,5))
g=sns.barplot(x=ratings['Series_Title'][:15],y=ratings['No_of_Votes'][:15])
g.set_title("Top Voted Series")
plt.xticks(rotation=-90)
plt.show()

# %% [markdown]
# #Findings
# As we can see in the graph above, Top 15 TV series of all time are listed according to the votes. In #1, we have 'Game of Thrones' with more than 1.75 millionn votes, followed by 'Breaking Bad' in #2 with over 1.50 million votes and in #3 we have 'The Walking Dead' with just over 750K votes.
#
#
# ---

# %%
fig,axs=plt.subplots(figsize=(20,7))
g=sns.barplot(x=ratings['Series_Title'][:15],y=ratings['IMDB_Rating'][:15])
g.set_title("Top Rated Series")
plt.xticks(rotation=-90)
plt.show()

# %% [markdown]
# #Findings
# Here, we can see the TV Series are laid out in a bar diagram according to their IMDB Ratings. We can see that the top spot goes to 'Breaking Bad' which has the IMDB Rating of 9.5. It is then followed by 'Game of Thrones' with IMDB Rating of 9.3, and subsequently by 'Sherlock' with the IMDB rating of 9.1.
#
#
# ---

# %% [markdown]
# #Breaking Bad
# Breaking Bad is an American neo-Western crime drama television series created and produced by Vince Gilligan. The show aired on AMC from January 20, 2008, to September 29, 2013, consisting of five seasons for a total of 62 episodes. It was set and filmed in Albuquerque, New Mexico, and tells the story of Walter White (Bryan Cranston), an underpaid, overqualified, and dispirited high school chemistry teacher who is struggling with a recent diagnosis of stage-three lung cancer. Walter turns to a life of crime, partnering with his former student Jesse Pinkman (Aaron Paul), by producing and distributing crystal meth to secure his family's financial future before he dies, while navigating the dangers of the criminal underworld. According to Gilligan, the title is a Southern colloquialism meaning "to raise hell". (Source: Wikipedia)
#
# ![375px-Breaking_Bad_title_card.png](data:image/png;base64,...)

# %% [markdown]
# #Sherlock
# Sherlock is a British mystery crime drama television series based on Sir Arthur Conan Doyle's Sherlock Holmes detective stories. Created by Steven Moffat and Mark Gatiss, it stars Benedict Cumberbatch as Sherlock Holmes and Martin Freeman as Doctor John Watson. Thirteen episodes have been produced, with four three-part series airing from 2010 to 2017 and a special episode that aired on 1 January 2016. The series is set in the present day, while the one-off special features a Victorian period fantasy resembling the original Holmes stories. Sherlock is produced by the British network BBC, along with Hartswood Films, with Moffat, Gatiss, Sue Vertue and Rebecca Eaton serving as executive producers. The series is supported by the American station WGBH-TV Boston for its Masterpiece anthology series on PBS, where it also airs in the United States. The series is primarily filmed in Cardiff, Wales, with North Gower Street in London used for exterior shots of Holmes and Watson's 221B Baker Street residence. (Source: Wikipedia)
#
# ![Sherlock_titlecard.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #Methodology
# Sorting the dataset according to the Runtime of each episodes.
#
# First, converting the 'Runtime_of_Episodes', which is an Object datatye into float,
#
# Second, Sorting the 'Runtime_of_Episodes' in an ascending order,
#
# Third, plotting a boxplot.

# %%
df.head(2)
# Out:
#       Series_Title Runtime_of_Series  ...          Star3 No_of_Votes
# 0  Game of Thrones       (2011–2019)  ...  Kit Harington     1773458
# 1     Breaking Bad       (2008–2013)  ...      Anna Gunn     1468887
#
# [2 rows x 9 columns]

# %%
df.dtypes
# Out:
# Series_Title            object
# Runtime_of_Series       object
# Runtime_of_Episodes     object
# Genre                   object
# IMDB_Rating            float64
# Star1                   object
# Star2                   object
# Star3                   object
# No_of_Votes              int64
# dtype: object

# %%
# #Displaying all the NaN values in 'Runtime_of_Episodes' column
# print(df[df['Runtime_of_Episodes'].isnull()])
# Out:
#                         Series_Title  ... No_of_Votes
# 330                 Raised by Wolves  ...       47063
# 407                          Ratched  ...       38629
# 620                           Cursed  ...       23360
# 680              Fate: The Winx Saga  ...       21438
# 684                      Warrior Nun  ...       21327
# 691                   Into the Night  ...       20934
# 704                             Away  ...       20535
# 721             The Flight Attendant  ...       20051
# 739                  Gangs of London  ...       19577
# 807                       Your Honor  ...       17404
# 1044                        Avenue 5  ...       12398
# 1122                  Why Women Kill  ...       11387
# 1167                     Dash & Lily  ...       10768
# 1218                       Giri/Haji  ...       10181
# 1282                       The Wilds  ...        9592
# 1305                 Brave New World  ...        9376
# ...

# %%
# ## Removing all NaN values use to numeric 
# df['Runtime_of_Episodes'] = pd.to_numeric(df['Runtime_of_Episodes'], errors='coerce')

# %%
# ## Removing all the NaN values
# df = df.dropna(subset=['Runtime_of_Episodes'])

# %%
# ## Converting 'Runtime_of_Episodes' into int datatype
# df['Runtime_of_Episodes'] = df['Runtime_of_Episodes'].astype(int)

# %%
# df.dtypes
# Out:
# Series_Title            object
# Runtime_of_Series       object
# Runtime_of_Episodes      int64
# Genre                   object
# IMDB_Rating            float64
# Star1                   object
# Star2                   object
# Star3                   object
# No_of_Votes              int64
# dtype: object

# %%
# df["Runtime_of_Episodes"].mean()

# %%
df.Runtime_of_Episodes.dtypes
# Out:
# dtype('O')

# %%
## Sorting by values
df.sort_values('Runtime_of_Episodes')
# Out:
#                       Series_Title  ... No_of_Votes
# 1399                 Mortal Kombat  ...        8509
# 1691                    Superjail!  ...        6490
# 806                Teen Titans Go!  ...       17411
# 412                         Poirot  ...       38313
# 1221               Inspector Morse  ...       10163
# ...                            ...  ...         ...
# 1879                Love & Anarchy  ...        5618
# 1895  Romanzo criminale - La serie  ...        5549
# 1933             We Are Who We Are  ...        5401
# 1969                      Helstrom  ...        5228
# 1986                       Toy Boy  ...        5150
#
# [2000 rows x 9 columns]

# %%
# df["Runtime_of_Episodes"].max()

# %%
# df["Runtime_of_Episodes"]==df["Runtime_of_Episodes"].max()

# %%
# df[df["Runtime_of_Episodes"]==df["Runtime_of_Episodes"].max()]

# %%
# df.Runtime_of_Episodes.plot(kind = 'box')

# %% [markdown]
# #Findings
#
# As we can see in the box plot above, the frequency of series having runtime between 0-200 is closely dispersed, meaning that most of the series are between 0-200 minutes. And the series having highest runtime is 'The Life & Times of Tim' i.e 900 minutes.
#
#
# ---

# %% [markdown]
# # Binary Classification
# Binary classification is dichotomization applied to a practical situation. In many practical binary classification problems, the two groups are not symmetric, and rather than overall accuracy, the relative proportion of different types of errors is of interest. For example, in medical testing, detecting a disease when it is not present (a false positive) is considered differently from not detecting a disease when it is present (a false negative). (Source: Wikipedia)
#
# Conditions:
#
# If 'IMDB_Rating' <= 7 ; Then 'Good' TV Series
#
# If 'IMDB_Rating' >=7 ; Then 'Bad' TV Series

# %%
## Importing necessary packages for Neural network models
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
print(f"Tensorflow version: {tf.version.VERSION}")
# Out:
# Tensorflow version: 2.7.0

# %%
## Importing Neural Network layers and other components

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dense, BatchNormalization, Dropout
from tensorflow.keras import optimizers

# %%
tf.random.set_seed(13)
tf.debugging.set_log_device_placement(False)

# %%
df.isna().sum(axis=1)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1995    0
# 1996    0
# 1997    0
# 1998    0
# 1999    0
# Length: 2000, dtype: int64

# %%
df.isna().sum(axis=0)
# Out:
# Series_Title            0
# Runtime_of_Series       0
# Runtime_of_Episodes    43
# Genre                   0
# IMDB_Rating             0
# Star1                   0
# Star2                   0
# Star3                   1
# No_of_Votes             0
# dtype: int64

# %%
df.isnull().sum(axis=0)
# Out:
# Series_Title            0
# Runtime_of_Series       0
# Runtime_of_Episodes    43
# Genre                   0
# IMDB_Rating             0
# Star1                   0
# Star2                   0
# Star3                   1
# No_of_Votes             0
# dtype: int64

# %%
df.isnull().sum(axis=1)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1995    0
# 1996    0
# 1997    0
# 1998    0
# 1999    0
# Length: 2000, dtype: int64

# %%
df=df.dropna()

# %%
df.isna().sum(axis=0)
# Out:
# Series_Title           0
# Runtime_of_Series      0
# Runtime_of_Episodes    0
# Genre                  0
# IMDB_Rating            0
# Star1                  0
# Star2                  0
# Star3                  0
# No_of_Votes            0
# dtype: int64

# %%
## Slicing the dataset and keeping last n rows of the dataset.
n = 50
temp_df = df[:n]
temp_df.shape
# Out:
# (50, 9)

# %%
## Sampling the dataset randomly and returning fraction from the dataset
df=df.sample(frac=1) ## This will randomly shuffle the dataset so that the data is not sorted in any way.

# %% [markdown]
# #Splitting the data into train/test splits

# %%
#Splitting the data into 60% train and 40% test 
train_dataset, temp_test_dataset = train_test_split(df, test_size= 0.4)

print(train_dataset.shape)
print(temp_test_dataset.shape)
# Out:
# (1173, 9)
# (783, 9)

# %%
## Splitting the test_dataset dataframe into 50% test and 50% validation 
test_dataset, valid_dataset = train_test_split(temp_test_dataset, test_size= 0.5)
print(test_dataset.shape)
print(valid_dataset.shape)
# Out:
# (391, 9)
# (392, 9)

# %%
print(f"Display the datatype of test_dataset: {type(test_dataset)}")
print(f"Trial dataset: {train_dataset.shape}")
print(f"Test dataset: {test_dataset.shape}")
print(f"Validation dataset: {valid_dataset.shape}")
# Out:
# Display the datatype of test_dataset: <class 'pandas.core.frame.DataFrame'>
# Trial dataset: (1173, 9)
# Test dataset: (391, 9)
# Validation dataset: (392, 9)

# %%
## Plotting the relationship between every two variables to spot any discrepancies
train_stats = train_dataset.describe()
sns.pairplot(train_stats[train_stats.columns], diag_kind= "kde")

# %%
## Stats on the train dataset to make sure it is in good shape
train_stats = train_dataset.describe()
train_stats = train_stats.transpose()
train_stats
# Out:
#               count          mean           std  ...      50%      75%       max
# IMDB_Rating  1173.0      7.590793      0.936335  ...      7.7      8.2       9.7
# No_of_Votes  1173.0  36469.768116  70896.412772  ...  12879.0  31305.0  854698.0
#
# [2 rows x 8 columns]

# %%
train_labels = train_dataset.pop('Runtime_of_Episodes')
test_labels = test_dataset.pop('Runtime_of_Episodes')
valid_labels = valid_dataset.pop('Runtime_of_Episodes')

# %% [markdown]
# #Data Normalization/Slicing
#
# ### subtracting the mean of the training data and dividing by the standard deviation of the training data

# %%
## defining the function to normalize the dataset
def norm(x):
    return (x - train_stats['mean']) / train_stats['std']
normed_train_data = norm(train_dataset)
normed_test_data = norm(test_dataset)
normed_valid_dataset = norm(valid_dataset)

# %%
normed_train_data.head(10)
# Out:
#      Genre  IMDB_Rating  No_of_Votes  ... Star1 Star2 Star3
# 1523   NaN    -7.038923    -0.407775  ...   NaN   NaN   NaN
# 1799   NaN     0.009833    -0.429567  ...   NaN   NaN   NaN
# 1077   NaN    -0.203765    -0.346460  ...   NaN   NaN   NaN
# 795    NaN    -1.058160    -0.262774  ...   NaN   NaN   NaN
# 409    NaN     0.009833     0.029765  ...   NaN   NaN   NaN
# 401    NaN     0.757429     0.035774  ...   NaN   NaN   NaN
# 546    NaN     0.757429    -0.118127  ...   NaN   NaN   NaN
# 1464   NaN    -0.310565    -0.401808  ...   NaN   NaN   NaN
# 1708   NaN     1.184626    -0.423671  ...   NaN   NaN   NaN
# 29     NaN     1.398225     4.116996  ...   NaN   NaN   NaN
#
# [10 rows x 8 columns]

# %%
print(r'Train/Test/Validate splits: ')
print(f'Train    : {normed_train_data.shape} ')
print(f'Test     : {normed_test_data.shape} ')
print(f'Validate : {normed_valid_dataset.shape} ')

print(r'Train/Test/Validate labels: ')
print(f'Train Labels : {train_labels.shape} ')
print(f'Test Labels  : {test_labels.shape} ')
print(f'Test Labels  : {valid_labels.shape} ')
# Out:
# Train/Test/Validate splits:
# Train    : (1173, 8)
# Test     : (391, 8)
# Validate : (392, 8)
# Train/Test/Validate labels:
# Train Labels : (1173,)
# Test Labels  : (391,)
# Test Labels  : (392,)

# %%
# We decalred a function for creating a model.
def build_model2_three_hidden_layers():
    # Keras model object created from Sequential class. This will be the container that contains all layers.
    model = Sequential()

    # The model so far is empty. It can be constructed by adding layers and compilation.
    # This Keras model with multiple hidden layers.
    
    # Input Layer with 32 Neurons
    model.add(Dense(32, input_shape = (normed_train_data.shape[1],)))    # Input layer => input_shape must be explicitly designated
#     model.add(Activation('relu')) # relu or sigmoid.
    
    model.add(Dense(32,Activation('relu')))                         # Hidden layer 1 => only output dimension should be designated (output dimension = # of Neurons = 32)
    
    
    model.add(Dense(64, Activation('relu')))                         # Hidden layer 2 => only output dimension should be designated (output dimension = # of Neurons = 64)
    
    
    model.add(Dense(128, Activation('relu')))                         # Hidden layer 3 => only output dimension should be designated (output dimension = # of Neurons = 128)

    
    model.add(Dense(1))                          # Output layer => output dimension = 1 since it is a regression problem
    
    # Activation: sigmoid, softmax, tanh, relu, LeakyReLU. 
    #Optimizer: SGD, Adam, RMSProp, etc. # https://www.tensorflow.org/api_docs/python/tf/keras/optimizers
    learning_rate = 0.001
    optimizer = optimizers.SGD(learning_rate)
    model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
                optimizer=optimizer,
                metrics=['accuracy']) 
    return model

model2 = build_model2_three_hidden_layers()
print('Here is a summary of this model: ')
model2.summary()
# Out:
# Here is a summary of this model:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 32)                288
#
#  dense_1 (Dense)             (None, 32)                1056
#
#  dense_2 (Dense)             (None, 64)                2112
#
#  dense_3 (Dense)             (None, 128)               8320
#
#  dense_4 (Dense)             (None, 1)                 129
#
# ...
# Total params: 11,905
# Trainable params: 11,905
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #AUC ROC Curve

# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split

# generate two class dataset
X, y = make_classification(n_samples=1000, n_classes=2, n_features=20, random_state=27)

# split into train-test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=27)

# %%
# train models
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

# logistic regression
model1 = LogisticRegression()
# knn
model2 = KNeighborsClassifier(n_neighbors=4)

# fit model
model1.fit(X_train, y_train)
model2.fit(X_train, y_train)

# predict probabilities
pred_prob1 = model1.predict_proba(X_test)
pred_prob2 = model2.predict_proba(X_test)

# %%
from sklearn.metrics import roc_curve

# roc curve for models
fpr1, tpr1, thresh1 = roc_curve(y_test, pred_prob1[:,1], pos_label=1)
fpr2, tpr2, thresh2 = roc_curve(y_test, pred_prob2[:,1], pos_label=1)

# roc curve for tpr = fpr 
random_probs = [0 for i in range(len(y_test))]
p_fpr, p_tpr, _ = roc_curve(y_test, random_probs, pos_label=1)

# %%
from sklearn.metrics import roc_auc_score

# auc scores
auc_score1 = roc_auc_score(y_test, pred_prob1[:,1])
auc_score2 = roc_auc_score(y_test, pred_prob2[:,1])

print(auc_score1, auc_score2)
# Out:
# 0.9762374461979914 0.9233769727403157

# %%
# matplotlib
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# plot roc curves
plt.plot(fpr1, tpr1, linestyle='--',color='blue', label='IMDB Rating')
plt.plot(fpr2, tpr2, linestyle='--',color='aqua', label='Runtime of Episodes')
plt.plot(p_fpr, p_tpr, linestyle='--', color='green')
# title
plt.title('ROC curve')
# x label
plt.xlabel('False Positive Rate')
# y label
plt.ylabel('True Positive rate')

plt.legend(loc='best')
plt.savefig('ROC',dpi=300)
plt.show();
